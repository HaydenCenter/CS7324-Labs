# %% [markdown]
# # Lab Five: Wide and Deep Network Architectures

# %% [markdown]
# In this lab, you will select a prediction task to perform on your dataset, evaluate two different deep learning architectures and tune hyper-parameters for each architecture. If any part of the assignment is not clear, ask the instructor to clarify.
#
# This report is worth 10% of the final grade. Please upload a report (<b>one per team</b>) with all code used, visualizations, and text in a rendered Jupyter notebook. Any visualizations that cannot be embedded in the notebook, please provide screenshots of the output. The results should be reproducible using your report. Please carefully describe every assumption and every step in your report.
#
# <b>Dataset Selection</b>
#
# Select a dataset similarly to lab one. That is, the dataset must be table data. In terms of generalization performance, it is helpful to have a large dataset for building a wide and deep network. It is also helpful to have many different categorical features to create the embeddings and cross-product embeddings. It is fine to perform binary classification, multi-class classification, or regression.

# %% [markdown]
# ## Preparation (4 pts)

# %% [markdown]
# <ul>
#     <li>[<b>1 points</b>] Define and prepare your class variables. Use proper variable representations (int, float, one-hot, etc.). Use pre-processing methods (as needed) for dimensionality reduction, scaling, etc. Remove variables that are not needed/useful for the analysis. Describe the final dataset that is used for classification/regression (include a description of any newly formed variables you created).
#     <li>[<b>1 points</b>] Identify groups of features in your data that should be combined into cross-product features. Provide justification for why these features should be crossed (or why some features should not be crossed).</li>
#     <li>[<b>1 points</b>] Choose and explain what metric(s) you will use to evaluate your algorithm’s performance. You should give a <b>detailed argument for why this (these) metric(s) are appropriate on your data</b>. That is, why is the metric appropriate for the task (e.g., in terms of the business case for the task). Please note: rarely is accuracy the best evaluation metric to use. Think deeply about an appropriate measure of performance.</li>
#     <li>[<b>1 points</b>] Choose the method you will use for dividing your data into training and testing (i.e., are you using Stratified 10-fold cross validation? Shuffle splits? Why?). <b>Explain why your chosen method is appropriate or use more than one method as appropriate</b>. Argue why your cross validation method is a realistic mirroring of how an algorithm would be used in practice. </li>
# </ul>

# %% [markdown]
# ### Dataset Preparation & Preprocessing

# %%
# Importing packages and reading in dataset
import numpy as np
import pandas as pd

print('Pandas:', pd.__version__)
print('Numpy:',  np.__version__)
# Out:
# Pandas: 1.2.1
# Numpy: 1.19.2

# %%
#read in csv file
merc_info = pd.read_csv('merc.csv')

#shuffle data
merc_info = merc_info.sample(frac=1)

#no null values, therefore do not need to impute any data
print(merc_info.info(show_counts=True))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13119 entries, 7428 to 1771
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         13119 non-null  object
#  1   year          13119 non-null  int64
#  2   price         13119 non-null  int64
#  3   transmission  13119 non-null  object
#  4   mileage       13119 non-null  int64
#  5   fuelType      13119 non-null  object
#  6   tax           13119 non-null  int64
#  7   mpg           13119 non-null  float64
#  8   engineSize    13119 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.0+ MB
# None

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

merc_info["log_price"] = np.log(merc_info["price"])
del merc_info["price"]

# define objects that can encode each variable as integer
categorical = ["model", "transmission", "fuelType"]
encoders = dict()

# train all encoders
for cat in categorical:
    # integer encoded variables
    encoders[cat] = LabelEncoder() # save the encoder
    merc_info[cat+'_int'] = encoders[cat].fit_transform(merc_info[cat])

# scale the numeric, continuous variables
numerical = ["year", "mileage", "tax", "mpg", "engineSize"]

for num in numerical:
    merc_info[num] = merc_info[num].astype(np.float)
    ss = StandardScaler()
    merc_info[num] = ss.fit_transform(merc_info[num].values.reshape(-1, 1))
    
categorical_headers_ints = [x+'_int' for x in categorical]
feature_columns = categorical_headers_ints + numerical

# Define features and target
X = merc_info.drop("log_price", axis=1)
y = merc_info["log_price"]

print(merc_info.info(show_counts=True))
merc_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13119 entries, 7428 to 1771
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   model             13119 non-null  object
#  1   year              13119 non-null  float64
#  2   transmission      13119 non-null  object
#  3   mileage           13119 non-null  float64
#  4   fuelType          13119 non-null  object
#  5   tax               13119 non-null  float64
#  6   mpg               13119 non-null  float64
#  7   engineSize        13119 non-null  float64
#  8   log_price         13119 non-null  float64
#  9   model_int         13119 non-null  int32
#  10  transmission_int  13119 non-null  int32
#  11  fuelType_int      13119 non-null  int32
# dtypes: float64(6), int32(3), object(3)
# memory usage: 1.2+ MB
# None
#             model      year transmission   mileage fuelType       tax  \
# 7428    GLE Class  0.765843    Semi-Auto -0.762929   Diesel  0.230284
# 13036    SL CLASS -7.774925    Automatic  2.208165   Petrol  2.145764
# 3845      E Class  0.765843    Semi-Auto -0.747440   Diesel  0.230284
# 4685      A Class  0.316329    Semi-Auto -0.025858   Petrol  0.230284
# 29        C Class -0.582700    Automatic  0.146037   Diesel -1.531958
# ...           ...       ...          ...       ...      ...       ...
# 1026      C Class -0.582700    Automatic  1.071579   Diesel -1.531958
# 8126      B Class -0.133186       Manual -0.658753   Diesel  0.230284
# 5976      E Class -0.582700    Semi-Auto  1.610640   Diesel  0.230284
# 7430      C Class  0.765843    Semi-Auto -0.819834   Diesel  0.230284
# 1771      E Class  0.765843    Automatic -0.935580   Diesel  0.230284
#
#             mpg  engineSize  log_price  model_int  transmission_int  \
# 7428  -1.468894    1.622053  10.819578         14                 3
# 13036 -2.007677    1.971457   9.371609         19                 0
# 3845   1.133030   -0.124964  10.164543          8                 3
# 4685  -0.187644   -0.823771   9.739909          0                 3
# 29     0.594248    0.049738   9.869310          2                 0
# ...         ...         ...        ...        ...               ...
# 1026   0.594248    0.049738   9.811263          2                 0
# 8126   0.692806    0.049738   9.615739          1                 1
# 5976   0.692806   -0.124964   9.864331          8                 3
# 7430   0.594248   -0.124964  10.315597          2                 3
# 1771  -0.121938   -0.124964  10.544815          8                 0
#
#        fuelType_int
# 7428              0
# 13036             3
# 3845              0
# 4685              3
# 29                0
# ...             ...
# 1026              0
# 8126              0
# 5976              0
# 7430              0
# 1771              0
#
# [13119 rows x 12 columns]

# %% [markdown]
# #### Explanation of Final Data Set
# hello

# %% [markdown]
# ### Making Crossed Columns

# %%
cross_columns = [['model', 'fuelType'],
                 ['transmission','fuelType'],
                 ['model','transmission']
                ]

cross_col_names = []
for cols_list in cross_columns:
    enc = LabelEncoder()
    
    X_crossed = merc_info[cols_list].apply(lambda x: '_'.join(x), axis=1)
    
    cross_col_name = '_'.join(cols_list)
    enc.fit(X_crossed)
    
    merc_info[cross_col_name] = enc.transform(X_crossed)
    
    # keep track of the new names of the crossed columns
    cross_col_names.append(cross_col_name)

# %% [markdown]
# ### Split Dataset into Training and Testing

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(merc_info,y,test_size=0.2,random_state=123)

X_train_df = pd.DataFrame(X_train, columns= merc_info.columns)
X_test_df = pd.DataFrame(X_test, columns= merc_info.columns)

# %% [markdown]
# #### Explanation of Dataset Split
# Our dataset is very large; it is made up about about 13,100 instances. Therefore, we are able to split our training and testing data by a 80-20 ratio.

# %% [markdown]
# #### Explanation of Evaluation Metrics
# MSE cuz regression

# %% [markdown]
# ## Modeling (5 pts)

# %% [markdown]
# <ul>
#     <li>[<b>2 points</b>] Create at least three combined wide and deep networks to classify your data using Keras. Visualize the performance of the network on the training data and validation data in the same plot versus the training iterations. Note: use the "history" return parameter that is part of Keras "fit" function to easily access this data. </li>
#     <li>[<b>2 points</b>] Investigate generalization performance by altering the number of layers in the deep branch of the network. Try at least two different number of layers. Use the method of cross validation and evaluation metric that you argued for at the beginning of the lab to select the number of layers that performs superiorly. </li>
#     <li>[<b>1 points</b>] Compare the performance of your best wide and deep network to a standard multi-layer perceptron (MLP). For classification tasks, use the receiver operating characteristic and area under the curve. For regression tasks, use Bland-Altman plots and residual variance calculations.  Use proper statistical method to compare the performance of different models.  </li>
# </ul>

# %% [markdown]
# ### Creating the Deep Network

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Activation, Input
from tensorflow.keras.layers import Embedding, Flatten, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping

optimizer = 'adam'
initializer = tf.keras.initializers.GlorotUniform()
loss = 'mean_squared_error'
metrics = 'mean_squared_error'
epochs = 256
batch_size = 512
verbose = 1
callbacks = [EarlyStopping(monitor='mean_squared_error', patience=8)]

X_train_cat = X_train_df[categorical_headers_ints].to_numpy()
X_train_num = X_train_df[numerical].to_numpy()
X_test_cat  = X_test_df[categorical_headers_ints].to_numpy()
X_test_num  = X_test_df[numerical].to_numpy()

# %%
# %%time

all_branch_outputs = [] # this is where we will keep track of output of each branch

# feed in the entire matrix of categorical variables
input_cat = Input(shape=(X_train_cat.shape[1],), name='categorical', dtype='int64')

# for each categorical variable
for idx,col in enumerate(categorical_headers_ints):
    
    # what the maximum integer value for this variable?
    # which is the same as the number of categories
    N = max(X_train_df[col].max(),X_test_df[col].max())+1 
    
    # this line of code does this: input_cat[:,idx]
    x = tf.gather(input_cat, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs in list to concatenate later
    all_branch_outputs.append(x)
    
input_num = Input(shape=(X_train_num.shape[1],), name='numeric')
x_dense = Dense(units=10, kernel_initializer=initializer, name='num_1')(input_num)

all_branch_outputs.append(x_dense)
        
# now concatenate the outputs and add a fully connected layer
deep_branch_0 = concatenate(all_branch_outputs, name='deep_concat')
deep_branch_1 = Dense(units=10, kernel_initializer=initializer, name='deep_1')(deep_branch_0)
deep_branch_2 = Dense(units=10, kernel_initializer=initializer, name='deep_2')(deep_branch_1)
deep_branch_3 = Dense(units=10,  kernel_initializer=initializer, name='deep_3')(deep_branch_2)

final_branch = Dense(units=1, name='output')(deep_branch_3)

model = Model(inputs=[input_cat, input_num], outputs=final_branch)

model.compile(optimizer=optimizer,
              loss=loss,
              metrics=metrics)

history = model.fit([X_train_cat, X_train_num], y_train,
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=callbacks,
                    validation_data=([X_test_cat, X_test_num], y_test))
# Out:
# Epoch 1/256
# 21/21 [==============================] - 0s 13ms/step - loss: 98.4575 - mean_squared_error: 98.4575 - val_loss: 95.1195 - val_mean_squared_error: 95.1195
# Epoch 2/256
# 21/21 [==============================] - 0s 3ms/step - loss: 90.4693 - mean_squared_error: 90.4693 - val_loss: 83.7197 - val_mean_squared_error: 83.7197
# Epoch 3/256
# 21/21 [==============================] - 0s 3ms/step - loss: 73.6636 - mean_squared_error: 73.6636 - val_loss: 59.0276 - val_mean_squared_error: 59.0276
# Epoch 4/256
# 21/21 [==============================] - 0s 3ms/step - loss: 41.2492 - mean_squared_error: 41.2492 - val_loss: 19.5977 - val_mean_squared_error: 19.5977
# Epoch 5/256
# 21/21 [==============================] - 0s 3ms/step - loss: 6.9628 - mean_squared_error: 6.9628 - val_loss: 0.2986 - val_mean_squared_error: 0.2986
# Epoch 6/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.5241 - mean_squared_error: 0.5241 - val_loss: 0.2192 - val_mean_squared_error: 0.2192
# Epoch 7/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1418 - mean_squared_error: 0.1418 - val_loss: 0.1075 - val_mean_squared_error: 0.1075
# Epoch 8/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0938 - mean_squared_error: 0.0938 - val_loss: 0.0731 - val_mean_squared_error: 0.0731
# Epoch 9/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0731 - mean_squared_error: 0.0731 - val_loss: 0.0634 - val_mean_squared_error: 0.0634
# Epoch 10/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0629 - mean_squared_error: 0.0629 - val_loss: 0.0555 - val_mean_squared_error: 0.0555
# Epoch 11/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0545 - mean_squared_error: 0.0545 - val_loss: 0.0485 - val_mean_squared_error: 0.0485
# Epoch 12/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0477 - mean_squared_error: 0.0477 - val_loss: 0.0442 - val_mean_squared_error: 0.0442
# Epoch 13/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0435 - mean_squared_error: 0.0435 - val_loss: 0.0405 - val_mean_squared_error: 0.0405
# Epoch 14/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0398 - mean_squared_error: 0.0398 - val_loss: 0.0377 - val_mean_squared_error: 0.0377
# Epoch 15/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0362 - mean_squared_error: 0.0362 - val_loss: 0.0348 - val_mean_squared_error: 0.0348
# Epoch 16/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.0334 - val_mean_squared_error: 0.0334
# Epoch 17/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0321 - mean_squared_error: 0.0321 - val_loss: 0.0315 - val_mean_squared_error: 0.0315
# Epoch 18/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0320 - mean_squared_error: 0.0320 - val_loss: 0.0309 - val_mean_squared_error: 0.0309
# Epoch 19/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0291 - mean_squared_error: 0.0291 - val_loss: 0.0298 - val_mean_squared_error: 0.0298
# Epoch 20/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0291 - mean_squared_error: 0.0291 - val_loss: 0.0307 - val_mean_squared_error: 0.0307
# Epoch 21/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
# Epoch 22/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0285 - val_mean_squared_error: 0.0285
# Epoch 23/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 24/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0268 - mean_squared_error: 0.0268 - val_loss: 0.0267 - val_mean_squared_error: 0.0267
# Epoch 25/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0258 - mean_squared_error: 0.0258 - val_loss: 0.0281 - val_mean_squared_error: 0.0281
# Epoch 26/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0259 - mean_squared_error: 0.0259 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 27/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0278 - val_mean_squared_error: 0.0278
# Epoch 28/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0267 - val_mean_squared_error: 0.0267
# Epoch 29/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0263 - mean_squared_error: 0.0263 - val_loss: 0.0278 - val_mean_squared_error: 0.0278
# Epoch 30/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 31/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 32/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 33/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 34/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 35/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0256 - mean_squared_error: 0.0256 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 36/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 37/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 38/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 39/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0278 - val_mean_squared_error: 0.0278
# Epoch 40/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Epoch 41/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 42/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 43/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 44/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 45/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Wall time: 4.57 s

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(history.history['mean_squared_error'])
plt.ylabel('Mean Squared Error')

plt.title('Training')
plt.subplot(1,2,2)
plt.yscale('log')
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation')
# Out:
# Text(0.5, 1.0, 'Validation')

# %% [markdown]
# ### Creating the Wide Networks

# %%
def crossed_outputs(idx, input_crossed):
    col = cross_col_names[idx]
    N = merc_info[col].max()+1
    x = tf.gather(input_crossed, 0, axis=1)
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    return x

# %%
X_train_crossed_0 = X_train_df[cross_col_names[0]].to_numpy()
X_test_crossed_0  = X_test_df[cross_col_names[0]].to_numpy()
input_crossed_0  = Input(shape=(1,), dtype='int64', name='crossed_categorical')
output_crossed_0 = crossed_outputs(0, input_crossed_0)

wide_branch_0 = Dense(units=1, kernel_initializer=initializer, name='wide_0')(output_crossed_0)

model = Model(inputs=input_crossed_0, outputs=wide_branch_0)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
X_train_crossed_1 = X_train_df[cross_col_names[1]].to_numpy()
X_test_crossed_1  = X_test_df[cross_col_names[1]].to_numpy()
input_crossed_1  = Input(shape=(1,), dtype='int64', name='crossed_categorical')
output_crossed_1 = crossed_outputs(1, input_crossed_1)

wide_branch_1 = Dense(units=1, kernel_initializer=initializer, name='wide_1')(output_crossed_1)

model = Model(inputs=input_crossed_1, outputs=wide_branch_1)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
X_train_crossed_2 = X_train_df[cross_col_names[2]].to_numpy()
X_test_crossed_2  = X_test_df[cross_col_names[2]].to_numpy()
input_crossed_2  = Input(shape=(1,), dtype='int64', name='crossed_categorical')
output_crossed_2 = crossed_outputs(2, input_crossed_2)

wide_branch_2 = Dense(units=1, kernel_initializer=initializer, name='wide_2')(output_crossed_2)

model = Model(inputs=input_crossed_2, outputs=wide_branch_2)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
X_train_crossed = X_train_df[cross_col_names].to_numpy()
X_test_crossed  = X_test_df[cross_col_names].to_numpy()

output_crossed = []
input_crossed = Input(shape=(X_train_crossed.shape[1],), dtype='int64', name='crossed_categorical')
for idx,col in enumerate(cross_col_names):
    N = merc_info[col].max()+1
    x = tf.gather(input_crossed, idx, axis=1)
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    output_crossed.append(x)

wide_branch = concatenate(output_crossed, name='wide_concat')
wide_branch_output = Dense(units=1, kernel_initializer=initializer, name='wide_output')(wide_branch)

model = Model(inputs=input_crossed, outputs=wide_branch_output)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %% [markdown]
# ### Combining the Networks

# %%
wide_deep_0 = concatenate([output_crossed_0, deep_branch_3], axis=1)
wide_deep_0 = Dense(units=1, kernel_initializer=initializer)(wide_deep_0)
model = Model(inputs=[input_crossed_0, input_cat, input_num], outputs=wide_deep_0)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit([X_train_crossed_0, X_train_cat, X_train_num], y_train,
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=callbacks,
                    validation_data=([X_test_crossed_0, X_test_cat, X_test_num], y_test))
# Out:
# Epoch 1/256
# 21/21 [==============================] - 0s 19ms/step - loss: 70.5516 - mean_squared_error: 70.5516 - val_loss: 53.4355 - val_mean_squared_error: 53.4355
# Epoch 2/256
# 21/21 [==============================] - 0s 4ms/step - loss: 37.3877 - mean_squared_error: 37.3877 - val_loss: 19.7293 - val_mean_squared_error: 19.7293
# Epoch 3/256
# 21/21 [==============================] - 0s 3ms/step - loss: 8.6774 - mean_squared_error: 8.6774 - val_loss: 0.8100 - val_mean_squared_error: 0.8100
# Epoch 4/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.2425 - mean_squared_error: 0.2425 - val_loss: 0.2854 - val_mean_squared_error: 0.2854
# Epoch 5/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.1209 - mean_squared_error: 0.1209 - val_loss: 0.0314 - val_mean_squared_error: 0.0314
# Epoch 6/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0324 - mean_squared_error: 0.0324 - val_loss: 0.0314 - val_mean_squared_error: 0.0314
# Epoch 7/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0264 - mean_squared_error: 0.0264 - val_loss: 0.0286 - val_mean_squared_error: 0.0286
# Epoch 8/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0282 - val_mean_squared_error: 0.0282
# Epoch 9/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 0.0280 - val_mean_squared_error: 0.0280
# Epoch 10/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Epoch 11/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 12/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Epoch 13/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 14/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 15/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0284 - val_mean_squared_error: 0.0284
# Epoch 16/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Epoch 17/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 18/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0270 - val_mean_squared_error: 0.0270
# Epoch 19/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 20/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 21/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0270 - val_mean_squared_error: 0.0270
# Epoch 22/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 23/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 24/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 25/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 26/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0270 - val_mean_squared_error: 0.0270
# Epoch 27/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 28/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 29/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 30/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 31/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 32/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 33/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 34/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 35/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 36/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0267 - val_mean_squared_error: 0.0267
# Epoch 37/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 38/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 39/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0270 - val_mean_squared_error: 0.0270
# Epoch 40/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 41/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 42/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0268 - val_mean_squared_error: 0.0268

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(history.history['mean_squared_error'])
plt.ylabel('Mean Squared Error')

plt.title('Training')
plt.subplot(1,2,2)
plt.yscale('log')
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation')
# Out:
# Text(0.5, 1.0, 'Validation')

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
wide_deep_1 = concatenate([output_crossed_1, deep_branch_3], axis=1)
wide_deep_1 = Dense(units=1, kernel_initializer=initializer)(wide_deep_1)
model = Model(inputs=[input_crossed_1, input_cat, input_num], outputs=wide_deep_1)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit([X_train_crossed_1, X_train_cat, X_train_num], y_train,
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=callbacks,
                    validation_data=([X_test_crossed_1, X_test_cat, X_test_num], y_test))
# Out:
# Epoch 1/256
# 21/21 [==============================] - 0s 13ms/step - loss: 0.1106 - mean_squared_error: 0.1106 - val_loss: 0.0296 - val_mean_squared_error: 0.0296
# Epoch 2/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0310 - mean_squared_error: 0.0310 - val_loss: 0.0296 - val_mean_squared_error: 0.0296
# Epoch 3/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0285 - val_mean_squared_error: 0.0285
# Epoch 4/256
# 21/21 [==============================] - ETA: 0s - loss: 0.0246 - mean_squared_error: 0.02 - 0s 3ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 5/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0286 - val_mean_squared_error: 0.0286
# Epoch 6/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0278 - val_mean_squared_error: 0.0278
# Epoch 7/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 8/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0288 - val_mean_squared_error: 0.0288
# Epoch 9/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 10/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 11/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0285 - val_mean_squared_error: 0.0285
# Epoch 12/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0286 - val_mean_squared_error: 0.0286
# Epoch 13/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0293 - val_mean_squared_error: 0.0293
# Epoch 14/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 15/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0245 - mean_squared_error: 0.0245 - val_loss: 0.0294 - val_mean_squared_error: 0.0294
# Epoch 16/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0255 - mean_squared_error: 0.0255 - val_loss: 0.0293 - val_mean_squared_error: 0.0293

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(history.history['mean_squared_error'])
plt.ylabel('Mean Squared Error')

plt.title('Training')
plt.subplot(1,2,2)
plt.yscale('log')
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation')
# Out:
# Text(0.5, 1.0, 'Validation')

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
wide_deep_2 = concatenate([output_crossed_2, deep_branch_3], axis=1)
wide_deep_2 = Dense(units=1, kernel_initializer=initializer)(wide_deep_2)
model = Model(inputs=[input_crossed_2, input_cat, input_num], outputs=wide_deep_2)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit([X_train_crossed_2, X_train_cat, X_train_num], y_train,
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=callbacks,
                    validation_data=([X_test_crossed_2, X_test_cat, X_test_num], y_test))
# Out:
# Epoch 1/256
# 21/21 [==============================] - 0s 12ms/step - loss: 86.4179 - mean_squared_error: 86.4179 - val_loss: 56.5543 - val_mean_squared_error: 56.5543
# Epoch 2/256
# 21/21 [==============================] - 0s 3ms/step - loss: 34.9943 - mean_squared_error: 34.9943 - val_loss: 13.8280 - val_mean_squared_error: 13.8280
# Epoch 3/256
# 21/21 [==============================] - 0s 3ms/step - loss: 4.6490 - mean_squared_error: 4.6490 - val_loss: 0.0366 - val_mean_squared_error: 0.0366
# Epoch 4/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2427 - mean_squared_error: 0.2427 - val_loss: 0.1820 - val_mean_squared_error: 0.1820
# Epoch 5/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0625 - mean_squared_error: 0.0625 - val_loss: 0.0402 - val_mean_squared_error: 0.0402
# Epoch 6/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 7/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 8/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 9/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 10/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 11/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 12/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 13/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 14/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 15/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 16/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 17/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 18/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 19/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 20/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 21/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 22/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 23/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 24/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0254 - val_mean_squared_error: 0.0254
# Epoch 25/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 26/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 27/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 28/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 29/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 30/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 31/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 32/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 33/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 34/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 35/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 36/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# Epoch 37/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# Epoch 38/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 39/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 40/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0254 - val_mean_squared_error: 0.0254
# Epoch 41/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0254 - val_mean_squared_error: 0.0254
# Epoch 42/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 43/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 44/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0256 - val_mean_squared_error: 0.0256

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(history.history['mean_squared_error'])
plt.ylabel('Mean Squared Error')

plt.title('Training')
plt.subplot(1,2,2)
plt.yscale('log')
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation')
# Out:
# Text(0.5, 1.0, 'Validation')

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
wide_deep = concatenate([wide_branch, deep_branch_3], axis=1)
wide_deep = Dense(units=1, kernel_initializer=initializer)(wide_deep)
model = Model(inputs=[input_crossed, input_cat, input_num], outputs=wide_deep)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit([X_train_crossed, X_train_cat, X_train_num], y_train,
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=callbacks,
                    validation_data=([X_test_crossed, X_test_cat, X_test_num], y_test))
# Out:
# Epoch 1/256
# 21/21 [==============================] - 0s 13ms/step - loss: 156.0689 - mean_squared_error: 156.0689 - val_loss: 110.1851 - val_mean_squared_error: 110.1851
# Epoch 2/256
# 21/21 [==============================] - 0s 3ms/step - loss: 83.3816 - mean_squared_error: 83.3816 - val_loss: 57.5184 - val_mean_squared_error: 57.5184
# Epoch 3/256
# 21/21 [==============================] - 0s 3ms/step - loss: 39.4050 - mean_squared_error: 39.4050 - val_loss: 21.3005 - val_mean_squared_error: 21.3005
# Epoch 4/256
# 21/21 [==============================] - 0s 3ms/step - loss: 10.6258 - mean_squared_error: 10.6258 - val_loss: 2.4131 - val_mean_squared_error: 2.4131
# Epoch 5/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6001 - mean_squared_error: 0.6001 - val_loss: 0.0633 - val_mean_squared_error: 0.0633
# Epoch 6/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0980 - mean_squared_error: 0.0980 - val_loss: 0.0603 - val_mean_squared_error: 0.0603
# Epoch 7/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0343 - mean_squared_error: 0.0343 - val_loss: 0.0314 - val_mean_squared_error: 0.0314
# Epoch 8/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0270 - mean_squared_error: 0.0270 - val_loss: 0.0302 - val_mean_squared_error: 0.0302
# Epoch 9/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0290 - val_mean_squared_error: 0.0290
# Epoch 10/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0289 - val_mean_squared_error: 0.0289
# Epoch 11/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0290 - val_mean_squared_error: 0.0290
# Epoch 12/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0284 - val_mean_squared_error: 0.0284
# Epoch 13/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
# Epoch 14/256
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0279 - val_mean_squared_error: 0.0279
# Epoch 15/256
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0282 - val_mean_squared_error: 0.0282
# Epoch 16/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
# Epoch 17/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 18/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0279 - val_mean_squared_error: 0.0279
# Epoch 19/256
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 20/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 21/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0274 - val_mean_squared_error: 0.0274
# Epoch 22/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 23/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 24/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 25/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 26/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0270 - val_mean_squared_error: 0.0270
# Epoch 27/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 28/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 29/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 30/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 31/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 32/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0277 - val_mean_squared_error: 0.0277
# Epoch 33/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 34/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 35/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 36/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0270 - val_mean_squared_error: 0.0270
# Epoch 37/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 38/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 39/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 40/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 41/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 42/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 43/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 44/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 45/256
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 46/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 47/256
# 21/21 [==============================] - 0s 4ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 48/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 49/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 50/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 51/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 52/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 53/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 54/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 55/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 56/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 57/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 58/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 59/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 60/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 61/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 62/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 63/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# Epoch 64/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0221 - mean_squared_error: 0.0221 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 65/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 66/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0258 - val_mean_squared_error: 0.0258

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(history.history['mean_squared_error'])
plt.ylabel('Mean Squared Error')

plt.title('Training')
plt.subplot(1,2,2)
plt.yscale('log')
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation')
# Out:
# Text(0.5, 1.0, 'Validation')

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %% [markdown]
# ### Altering the Number of Layers

# %% [markdown]
# #### Cross Validation

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=10, shuffle=True, random_state=1234)

X_crossed = merc_info[cross_col_names].to_numpy()
X_cat     = merc_info[categorical_headers_ints].to_numpy()
X_num     = merc_info[numerical].to_numpy()
y         = merc_info['log_price'].to_numpy()

deep_branches = [
    deep_branch_0,
    deep_branch_1,
    deep_branch_2,
    deep_branch_3
]

eval_scores = {}
for model_no, deep_branch in enumerate(deep_branches):
    
    fold_no = 0
    eval_scores[model_no] = []
    for train_index, test_index in kf.split(X, y):
        X_train_crossed, X_test_crossed = X_crossed[train_index], X_crossed[test_index]
        X_train_cat,     X_test_cat     = X_cat[train_index],     X_cat[test_index]
        X_train_num,     X_test_num     = X_num[train_index],     X_num[test_index]
        y_train,         y_test         = y[train_index],         y[test_index]
        
        wide_deep = concatenate([wide_branch, deep_branch], axis=1)
        wide_deep = Dense(units=1, kernel_initializer=initializer)(wide_deep)
        model = Model(inputs=[input_crossed, input_cat, input_num], outputs=wide_deep)
        model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
        history = model.fit([X_train_crossed, X_train_cat, X_train_num], y_train,
                            epochs=epochs, batch_size=batch_size, callbacks = callbacks, verbose=0)

        scores = model.evaluate([X_test_crossed, X_test_cat, X_test_num], y_test, verbose=0)
        print(f"SCORE FOR MODEL {model_no} FOLD {fold_no}: MSE = {round(scores[1], 5)})")
        
        eval_scores[model_no].append(scores[1])
    
        fold_no += 1
# Out:
# SCORE FOR MODEL 0 FOLD 0: MSE = 0.02795)
# SCORE FOR MODEL 0 FOLD 1: MSE = 0.02607)
# SCORE FOR MODEL 0 FOLD 2: MSE = 0.01911)
# SCORE FOR MODEL 0 FOLD 3: MSE = 0.02131)
# SCORE FOR MODEL 0 FOLD 4: MSE = 0.02049)
# SCORE FOR MODEL 0 FOLD 5: MSE = 0.02086)
# SCORE FOR MODEL 0 FOLD 6: MSE = 0.01773)
# SCORE FOR MODEL 0 FOLD 7: MSE = 0.01819)
# SCORE FOR MODEL 0 FOLD 8: MSE = 0.04043)
# SCORE FOR MODEL 0 FOLD 9: MSE = 0.02033)
# SCORE FOR MODEL 1 FOLD 0: MSE = 0.02343)
# SCORE FOR MODEL 1 FOLD 1: MSE = 0.0218)
# SCORE FOR MODEL 1 FOLD 2: MSE = 0.01908)
# SCORE FOR MODEL 1 FOLD 3: MSE = 0.02)
# SCORE FOR MODEL 1 FOLD 4: MSE = 0.02066)
# SCORE FOR MODEL 1 FOLD 5: MSE = 0.02067)
# SCORE FOR MODEL 1 FOLD 6: MSE = 0.01745)
# SCORE FOR MODEL 1 FOLD 7: MSE = 0.01848)
# SCORE FOR MODEL 1 FOLD 8: MSE = 0.04059)
# SCORE FOR MODEL 1 FOLD 9: MSE = 0.02022)
# SCORE FOR MODEL 2 FOLD 0: MSE = 0.02723)
# SCORE FOR MODEL 2 FOLD 1: MSE = 0.02365)
# SCORE FOR MODEL 2 FOLD 2: MSE = 0.01978)
# SCORE FOR MODEL 2 FOLD 3: MSE = 0.01998)
# SCORE FOR MODEL 2 FOLD 4: MSE = 0.02034)
# SCORE FOR MODEL 2 FOLD 5: MSE = 0.02114)
# SCORE FOR MODEL 2 FOLD 6: MSE = 0.01687)
# SCORE FOR MODEL 2 FOLD 7: MSE = 0.01836)
# SCORE FOR MODEL 2 FOLD 8: MSE = 0.0409)
# SCORE FOR MODEL 2 FOLD 9: MSE = 0.02045)
# SCORE FOR MODEL 3 FOLD 0: MSE = 0.0242)
# SCORE FOR MODEL 3 FOLD 1: MSE = 0.02086)
# SCORE FOR MODEL 3 FOLD 2: MSE = 0.01935)
# SCORE FOR MODEL 3 FOLD 3: MSE = 0.02009)
# SCORE FOR MODEL 3 FOLD 4: MSE = 0.02064)
# SCORE FOR MODEL 3 FOLD 5: MSE = 0.02199)
# SCORE FOR MODEL 3 FOLD 6: MSE = 0.01674)
# SCORE FOR MODEL 3 FOLD 7: MSE = 0.01919)
# SCORE FOR MODEL 3 FOLD 8: MSE = 0.04103)
# SCORE FOR MODEL 3 FOLD 9: MSE = 0.02103)

# %%
scores = [np.mean(eval_scores[k]) for k in eval_scores]
best_model = np.argmin(scores)

wide_deep = concatenate([wide_branch, deep_branches[best_model]], axis=1)
wide_deep = Dense(units=1, kernel_initializer=initializer)(wide_deep)
best_model = Model(inputs=[input_crossed, input_cat, input_num], outputs=wide_deep)
best_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

plot_model(
    best_model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
print(eval_scores)
print(scores)
# Out:
# {0: [0.027952158823609352, 0.02606581151485443, 0.019109439104795456, 0.02131139114499092, 0.020486364141106606, 0.020855916664004326, 0.01773105561733246, 0.01818588376045227, 0.040430620312690735, 0.02032594382762909], 1: [0.02342943102121353, 0.02180330641567707, 0.01908138580620289, 0.019995003938674927, 0.020659608766436577, 0.020674774423241615, 0.017447011545300484, 0.018477313220500946, 0.04059075564146042, 0.02021516114473343], 2: [0.02722589299082756, 0.023653747513890266, 0.01978171430528164, 0.01998141035437584, 0.020344557240605354, 0.021139532327651978, 0.016870763152837753, 0.01836390420794487, 0.040899064391851425, 0.020453812554478645], 3: [0.024196481332182884, 0.020855648443102837, 0.019352704286575317, 0.02009236253798008, 0.020641915500164032, 0.021985145285725594, 0.01673562079668045, 0.01919354312121868, 0.04102673381567001, 0.021032972261309624]}
# [0.023245458491146564, 0.02223737519234419, 0.022871439903974534, 0.02251131273806095]

# %% [markdown]
# ## Exceptional Work (1 pt)

# %% [markdown]
# <ul>
#     <li> 5000 students: You have free reign to provide additional analyses. </li>
#     <li>One idea (<b>required for 7000 level students</b>): Capture the embedding weights from the deep network and (<b>if needed</b>) perform dimensionality reduction on the output of these embedding layers (<b>only if needed</b>). That is, pass the observations into the network, save the embedded weights (called embeddings), and then perform  dimensionality reduction in order to visualize results. Visualize and explain any clusters in the data. </li>
# </ul>
