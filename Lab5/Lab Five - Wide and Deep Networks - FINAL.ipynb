# %% [markdown]
# # Lab Five: Wide and Deep Network Architectures

# %% [markdown]
# In this lab, you will select a prediction task to perform on your dataset, evaluate two different deep learning architectures and tune hyper-parameters for each architecture. If any part of the assignment is not clear, ask the instructor to clarify.
#
# This report is worth 10% of the final grade. Please upload a report (<b>one per team</b>) with all code used, visualizations, and text in a rendered Jupyter notebook. Any visualizations that cannot be embedded in the notebook, please provide screenshots of the output. The results should be reproducible using your report. Please carefully describe every assumption and every step in your report.
#
# <b>Dataset Selection</b>
#
# Select a dataset similarly to lab one. That is, the dataset must be table data. In terms of generalization performance, it is helpful to have a large dataset for building a wide and deep network. It is also helpful to have many different categorical features to create the embeddings and cross-product embeddings. It is fine to perform binary classification, multi-class classification, or regression.

# %% [markdown]
# ## Preparation (4 pts)

# %% [markdown]
# <ul>
#     <li>[<b>1 points</b>] Define and prepare your class variables. Use proper variable representations (int, float, one-hot, etc.). Use pre-processing methods (as needed) for dimensionality reduction, scaling, etc. Remove variables that are not needed/useful for the analysis. Describe the final dataset that is used for classification/regression (include a description of any newly formed variables you created).
#     <li>[<b>1 points</b>] Identify groups of features in your data that should be combined into cross-product features. Provide justification for why these features should be crossed (or why some features should not be crossed).</li>
#     <li>[<b>1 points</b>] Choose and explain what metric(s) you will use to evaluate your algorithm’s performance. You should give a <b>detailed argument for why this (these) metric(s) are appropriate on your data</b>. That is, why is the metric appropriate for the task (e.g., in terms of the business case for the task). Please note: rarely is accuracy the best evaluation metric to use. Think deeply about an appropriate measure of performance.</li>
#     <li>[<b>1 points</b>] Choose the method you will use for dividing your data into training and testing (i.e., are you using Stratified 10-fold cross validation? Shuffle splits? Why?). <b>Explain why your chosen method is appropriate or use more than one method as appropriate</b>. Argue why your cross validation method is a realistic mirroring of how an algorithm would be used in practice. </li>
# </ul>

# %% [markdown]
# ### Dataset Preparation & Preprocessing

# %%
# Importing packages and reading in dataset
import numpy as np
import pandas as pd

print('Pandas:', pd.__version__)
print('Numpy:',  np.__version__)
# Out:
# Pandas: 1.1.3
# Numpy: 1.19.2

# %%
#read in csv file
merc_info = pd.read_csv('merc.csv')

#shuffle data
merc_info = merc_info.sample(frac=1)

#no null values, therefore do not need to impute any data
# print(merc_info.info(show_counts=True))

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

merc_info["log_price"] = np.log(merc_info["price"])
del merc_info["price"]

# define objects that can encode each variable as integer
categorical = ["model", "transmission", "fuelType"]
encoders = dict()

# train all encoders
for cat in categorical:
    # integer encoded variables
    encoders[cat] = LabelEncoder() # save the encoder
    merc_info[cat+'_int'] = encoders[cat].fit_transform(merc_info[cat])

# scale the numeric, continuous variables
numerical = ["year", "mileage", "tax", "mpg", "engineSize"]

for num in numerical:
    merc_info[num] = merc_info[num].astype(np.float)
    ss = StandardScaler()
    merc_info[num] = ss.fit_transform(merc_info[num].values.reshape(-1, 1))
    
categorical_headers_ints = [x+'_int' for x in categorical]
feature_columns = categorical_headers_ints + numerical

# Define features and target
X = merc_info.drop("log_price", axis=1)
y = merc_info["log_price"]

# print(merc_info.info(show_counts=True))
merc_info
# Out:
#             model      year transmission   mileage fuelType       tax  \
# 8024     SL CLASS  0.765843    Automatic -1.011043   Petrol  0.230284
# 7502      C Class  0.765843    Semi-Auto -0.898462   Diesel  0.230284
# 6763      B Class  0.765843    Semi-Auto -0.901673   Diesel  0.230284
# 9245      C Class -0.582700    Semi-Auto  1.129523   Diesel -1.531958
# 12087     E Class -0.133186    Automatic  1.078332   Diesel -1.685196
# ...           ...       ...          ...       ...      ...       ...
# 11998     E Class -1.032214    Automatic  0.682407   Diesel -0.076193
# 12110   GLA Class -0.133186    Automatic  0.211301   Diesel -1.531958
# 3126      E Class -0.133186    Semi-Auto  0.767079   Diesel  0.230284
# 1333      A Class  0.765843       Manual -0.381926   Petrol  0.230284
# 5496      C Class -0.582700    Semi-Auto -0.088430   Diesel -1.685196
#
#             mpg  engineSize  log_price  model_int  transmission_int  \
# 8024  -1.784279    5.989596  11.287266         19                 0
# 7502   0.088318   -0.124964  10.312247          2                 3
# 6763   0.324857   -0.998472  10.081592          1                 3
# 9245   0.410273    0.049738   9.804992          2                 3
# 12087  0.797934   -0.124964   9.852194          8                 0
# ...         ...         ...        ...        ...               ...
# 11998  0.088318    0.049738   9.710813          8                 0
# 12110  0.594248    0.049738   9.740969         11                 0
# 3126   1.133030   -0.124964   9.902487          8                 3
# 1333  -1.751427   -1.347876   9.902987          0                 1
# 5496   0.797934    0.049738  10.038455          2                 3
#
#        fuelType_int
# 8024              3
# 7502              0
# 6763              0
# 9245              0
# 12087             0
# ...             ...
# 11998             0
# 12110             0
# 3126              0
# 1333              3
# 5496              0
#
# [13119 rows x 12 columns]

# %% [markdown]
# #### Explanation of Final Data Set
# hello

# %% [markdown]
# ### Making Crossed Columns

# %%
cross_columns = [['model', 'fuelType'],
                 ['transmission','fuelType'],
                 ['model','transmission']
                ]

cross_col_names = []
for cols_list in cross_columns:
    enc = LabelEncoder()
    
    X_crossed = merc_info[cols_list].apply(lambda x: '_'.join(x), axis=1)
    
    cross_col_name = '_'.join(cols_list)
    enc.fit(X_crossed)
    
    merc_info[cross_col_name] = enc.transform(X_crossed)
    
    # keep track of the new names of the crossed columns
    cross_col_names.append(cross_col_name)

# %% [markdown]
# ### Split Dataset into Training and Testing

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(merc_info,y,test_size=0.2,random_state=123)

X_train_df = pd.DataFrame(X_train, columns= merc_info.columns)
X_test_df = pd.DataFrame(X_test, columns= merc_info.columns)

# %% [markdown]
# #### Explanation of Dataset Split
# Our dataset is very large; it is made up about about 13,100 instances. Therefore, we are able to split our training and testing data by a 80-20 ratio.

# %% [markdown]
# #### Explanation of Evaluation Metrics
# MSE cuz regression

# %% [markdown]
# ## Modeling (5 pts)

# %% [markdown]
# <ul>
#     <li>[<b>2 points</b>] Create at least three combined wide and deep networks to classify your data using Keras. Visualize the performance of the network on the training data and validation data in the same plot versus the training iterations. Note: use the "history" return parameter that is part of Keras "fit" function to easily access this data. </li>
#     <li>[<b>2 points</b>] Investigate generalization performance by altering the number of layers in the deep branch of the network. Try at least two different number of layers. Use the method of cross validation and evaluation metric that you argued for at the beginning of the lab to select the number of layers that performs superiorly. </li>
#     <li>[<b>1 points</b>] Compare the performance of your best wide and deep network to a standard multi-layer perceptron (MLP). For classification tasks, use the receiver operating characteristic and area under the curve. For regression tasks, use Bland-Altman plots and residual variance calculations.  Use proper statistical method to compare the performance of different models.  </li>
# </ul>

# %% [markdown]
# ### Creating the Deep Network

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Activation, Input
from tensorflow.keras.layers import Embedding, Flatten, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping

optimizer = 'adam'
initializer = tf.keras.initializers.GlorotUniform()
loss = 'mean_squared_error'
metrics = 'mean_squared_error'
epochs = 256
batch_size = 512
verbose = 1
callbacks = [EarlyStopping(monitor='mean_squared_error', patience=8)]

X_train_cat = X_train_df[categorical_headers_ints].to_numpy()
X_train_num = X_train_df[numerical].to_numpy()
X_test_cat  = X_test_df[categorical_headers_ints].to_numpy()
X_test_num  = X_test_df[numerical].to_numpy()

# %%
# %%time

all_branch_outputs = [] # this is where we will keep track of output of each branch

# feed in the entire matrix of categorical variables
input_cat = Input(shape=(X_train_cat.shape[1],), name='categorical', dtype='int64')

# for each categorical variable
for idx,col in enumerate(categorical_headers_ints):
    
    # what the maximum integer value for this variable?
    # which is the same as the number of categories
    N = max(X_train_df[col].max(),X_test_df[col].max())+1 
    
    # this line of code does this: input_cat[:,idx]
    x = tf.gather(input_cat, idx, axis=1)
    
    # now use an embedding to deal with integers as if they were one hot encoded
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    
    # save these outputs in list to concatenate later
    all_branch_outputs.append(x)
    
input_num = Input(shape=(X_train_num.shape[1],), name='numeric')
x_dense = Dense(units=10, kernel_initializer=initializer, name='num_1')(input_num)

all_branch_outputs.append(x_dense)
        
# now concatenate the outputs and add a fully connected layer
deep_branch_0 = concatenate(all_branch_outputs, name='deep_concat')
deep_branch_1 = Dense(units=10, kernel_initializer=initializer, name='deep_1')(deep_branch_0)
deep_branch_2 = Dense(units=10, kernel_initializer=initializer, name='deep_2')(deep_branch_1)
deep_branch_3 = Dense(units=10,  kernel_initializer=initializer, name='deep_3')(deep_branch_2)

final_branch = Dense(units=1, name='output')(deep_branch_3)

model = Model(inputs=[input_cat, input_num], outputs=final_branch)

model.compile(optimizer=optimizer,
              loss=loss,
              metrics=metrics)

history = model.fit([X_train_cat, X_train_num], y_train,
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=callbacks,
                    validation_data=([X_test_cat, X_test_num], y_test))
# Out:
# Epoch 1/256
# 21/21 [==============================] - 1s 26ms/step - loss: 99.7773 - mean_squared_error: 99.7773 - val_loss: 95.4821 - val_mean_squared_error: 95.4821
# Epoch 2/256
# 21/21 [==============================] - 0s 3ms/step - loss: 93.0651 - mean_squared_error: 93.0651 - val_loss: 83.8151 - val_mean_squared_error: 83.8151
# Epoch 3/256
# 21/21 [==============================] - 0s 3ms/step - loss: 78.3267 - mean_squared_error: 78.3267 - val_loss: 57.3086 - val_mean_squared_error: 57.3086
# Epoch 4/256
# 21/21 [==============================] - 0s 3ms/step - loss: 47.5360 - mean_squared_error: 47.5360 - val_loss: 15.7221 - val_mean_squared_error: 15.7221
# Epoch 5/256
# 21/21 [==============================] - 0s 3ms/step - loss: 8.7692 - mean_squared_error: 8.7692 - val_loss: 0.4623 - val_mean_squared_error: 0.4623
# Epoch 6/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.6624 - mean_squared_error: 0.6624 - val_loss: 0.0581 - val_mean_squared_error: 0.0581
# Epoch 7/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0686 - mean_squared_error: 0.0686 - val_loss: 0.0559 - val_mean_squared_error: 0.0559
# Epoch 8/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0502 - mean_squared_error: 0.0502 - val_loss: 0.0407 - val_mean_squared_error: 0.0407
# Epoch 9/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0408 - mean_squared_error: 0.0408 - val_loss: 0.0365 - val_mean_squared_error: 0.0365
# Epoch 10/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.0344 - val_mean_squared_error: 0.0344
# Epoch 11/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0407 - mean_squared_error: 0.0407 - val_loss: 0.0314 - val_mean_squared_error: 0.0314
# Epoch 12/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0330 - mean_squared_error: 0.0330 - val_loss: 0.0313 - val_mean_squared_error: 0.0313
# Epoch 13/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.0294 - val_mean_squared_error: 0.0294
# Epoch 14/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0294 - mean_squared_error: 0.0294 - val_loss: 0.0280 - val_mean_squared_error: 0.0280
# Epoch 15/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0339 - mean_squared_error: 0.0339 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 16/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Epoch 17/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0268 - mean_squared_error: 0.0268 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 18/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 19/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# Epoch 20/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# Epoch 21/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# Epoch 22/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0261 - mean_squared_error: 0.0261 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 23/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0273 - mean_squared_error: 0.0273 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 24/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 25/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 26/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 27/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 28/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0254 - val_mean_squared_error: 0.0254
# Epoch 29/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# Epoch 30/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 31/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 32/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0256 - mean_squared_error: 0.0256 - val_loss: 0.0252 - val_mean_squared_error: 0.0252
# Epoch 33/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 34/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 35/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# Epoch 36/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0314 - mean_squared_error: 0.0314 - val_loss: 0.0226 - val_mean_squared_error: 0.0226
# CPU times: user 3.86 s, sys: 1.05 s, total: 4.91 s
# Wall time: 3.15 s

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(history.history['mean_squared_error'])
plt.ylabel('Mean Squared Error')

plt.title('Training')
plt.subplot(1,2,2)
plt.yscale('log')
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation')
# Out:
# Text(0.5, 1.0, 'Validation')

# %% [markdown]
# ### Creating the Wide Networks

# %%
def crossed_outputs(idx, input_crossed):
    col = cross_col_names[idx]
    N = merc_info[col].max()+1
    x = tf.gather(input_crossed, 0, axis=1)
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    return x

# %%
X_train_crossed_0 = X_train_df[cross_col_names[0]].to_numpy()
X_test_crossed_0  = X_test_df[cross_col_names[0]].to_numpy()
input_crossed_0  = Input(shape=(1,), dtype='int64', name='crossed_categorical')
output_crossed_0 = crossed_outputs(0, input_crossed_0)

wide_branch_0 = Dense(units=1, kernel_initializer=initializer, name='wide_0')(output_crossed_0)

model = Model(inputs=input_crossed_0, outputs=wide_branch_0)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
X_train_crossed_1 = X_train_df[cross_col_names[1]].to_numpy()
X_test_crossed_1  = X_test_df[cross_col_names[1]].to_numpy()
input_crossed_1  = Input(shape=(1,), dtype='int64', name='crossed_categorical')
output_crossed_1 = crossed_outputs(1, input_crossed_1)

wide_branch_1 = Dense(units=1, kernel_initializer=initializer, name='wide_1')(output_crossed_1)

model = Model(inputs=input_crossed_1, outputs=wide_branch_1)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
X_train_crossed_2 = X_train_df[cross_col_names[2]].to_numpy()
X_test_crossed_2  = X_test_df[cross_col_names[2]].to_numpy()
input_crossed_2  = Input(shape=(1,), dtype='int64', name='crossed_categorical')
output_crossed_2 = crossed_outputs(2, input_crossed_2)

wide_branch_2 = Dense(units=1, kernel_initializer=initializer, name='wide_2')(output_crossed_2)

model = Model(inputs=input_crossed_2, outputs=wide_branch_2)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
X_train_crossed = X_train_df[cross_col_names].to_numpy()
X_test_crossed  = X_test_df[cross_col_names].to_numpy()

output_crossed = []
input_crossed = Input(shape=(X_train_crossed.shape[1],), dtype='int64', name='crossed_categorical')
for idx,col in enumerate(cross_col_names):
    N = merc_info[col].max()+1
    x = tf.gather(input_crossed, idx, axis=1)
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(x)
    output_crossed.append(x)

wide_branch = concatenate(output_crossed, name='wide_concat')
wide_branch_output = Dense(units=1, kernel_initializer=initializer, name='wide_output')(wide_branch)

model = Model(inputs=input_crossed, outputs=wide_branch_output)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %% [markdown]
# ### Combining the Networks

# %%
wide_deep_0 = concatenate([output_crossed_0, deep_branch_3], axis=1)
wide_deep_0 = Dense(units=1, kernel_initializer=initializer)(wide_deep_0)
model = Model(inputs=[input_crossed_0, input_cat, input_num], outputs=wide_deep_0)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit([X_train_crossed_0, X_train_cat, X_train_num], y_train,
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=callbacks,
                    validation_data=([X_test_crossed_0, X_test_cat, X_test_num], y_test))
# Out:
# Epoch 1/256
# 21/21 [==============================] - 1s 9ms/step - loss: 46.6912 - mean_squared_error: 46.6912 - val_loss: 20.6305 - val_mean_squared_error: 20.6305
# Epoch 2/256
# 21/21 [==============================] - 0s 3ms/step - loss: 14.0206 - mean_squared_error: 14.0206 - val_loss: 0.8826 - val_mean_squared_error: 0.8826
# Epoch 3/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3639 - mean_squared_error: 0.3639 - val_loss: 0.3159 - val_mean_squared_error: 0.3159
# Epoch 4/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2003 - mean_squared_error: 0.2003 - val_loss: 0.0319 - val_mean_squared_error: 0.0319
# Epoch 5/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0395 - mean_squared_error: 0.0395 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 6/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0313 - mean_squared_error: 0.0313 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 7/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 8/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 9/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 10/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 11/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0307 - mean_squared_error: 0.0307 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 12/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 13/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 14/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 15/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 16/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 17/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 18/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 19/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 20/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 21/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 22/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 23/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0230 - val_mean_squared_error: 0.0230
# Epoch 24/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0231 - val_mean_squared_error: 0.0231
# Epoch 25/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0237 - mean_squared_error: 0.0237 - val_loss: 0.0245 - val_mean_squared_error: 0.0245

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(history.history['mean_squared_error'])
plt.ylabel('Mean Squared Error')

plt.title('Training')
plt.subplot(1,2,2)
plt.yscale('log')
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation')
# Out:
# Text(0.5, 1.0, 'Validation')

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
wide_deep_1 = concatenate([output_crossed_1, deep_branch_3], axis=1)
wide_deep_1 = Dense(units=1, kernel_initializer=initializer)(wide_deep_1)
model = Model(inputs=[input_crossed_1, input_cat, input_num], outputs=wide_deep_1)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit([X_train_crossed_1, X_train_cat, X_train_num], y_train,
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=callbacks,
                    validation_data=([X_test_crossed_1, X_test_cat, X_test_num], y_test))
# Out:
# Epoch 1/256
# 21/21 [==============================] - 1s 9ms/step - loss: 141.1269 - mean_squared_error: 141.1269 - val_loss: 95.9548 - val_mean_squared_error: 95.9548
# Epoch 2/256
# 21/21 [==============================] - 0s 3ms/step - loss: 84.2896 - mean_squared_error: 84.2896 - val_loss: 52.6150 - val_mean_squared_error: 52.6150
# Epoch 3/256
# 21/21 [==============================] - 0s 2ms/step - loss: 43.0175 - mean_squared_error: 43.0175 - val_loss: 16.8900 - val_mean_squared_error: 16.8900
# Epoch 4/256
# 21/21 [==============================] - 0s 3ms/step - loss: 11.1612 - mean_squared_error: 11.1612 - val_loss: 0.6725 - val_mean_squared_error: 0.6725
# Epoch 5/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.2727 - mean_squared_error: 0.2727 - val_loss: 0.1938 - val_mean_squared_error: 0.1938
# Epoch 6/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.1512 - mean_squared_error: 0.1512 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 7/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0274 - val_mean_squared_error: 0.0274
# Epoch 8/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0244 - val_mean_squared_error: 0.0244
# Epoch 9/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# Epoch 10/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# Epoch 11/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 12/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 13/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0255 - mean_squared_error: 0.0255 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# Epoch 14/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 15/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 16/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 17/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.0248 - val_mean_squared_error: 0.0248
# Epoch 18/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 19/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 20/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 21/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 22/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0259 - mean_squared_error: 0.0259 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 23/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 24/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# Epoch 25/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 26/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 27/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0246 - mean_squared_error: 0.0246 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# Epoch 28/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0235 - val_mean_squared_error: 0.0235

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(history.history['mean_squared_error'])
plt.ylabel('Mean Squared Error')

plt.title('Training')
plt.subplot(1,2,2)
plt.yscale('log')
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation')
# Out:
# Text(0.5, 1.0, 'Validation')

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
wide_deep_2 = concatenate([output_crossed_2, deep_branch_3], axis=1)
wide_deep_2 = Dense(units=1, kernel_initializer=initializer)(wide_deep_2)
model = Model(inputs=[input_crossed_2, input_cat, input_num], outputs=wide_deep_2)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit([X_train_crossed_2, X_train_cat, X_train_num], y_train,
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=callbacks,
                    validation_data=([X_test_crossed_2, X_test_cat, X_test_num], y_test))
# Out:
# Epoch 1/256
# 21/21 [==============================] - 1s 8ms/step - loss: 475.4631 - mean_squared_error: 475.4631 - val_loss: 334.3450 - val_mean_squared_error: 334.3450
# Epoch 2/256
# 21/21 [==============================] - 0s 3ms/step - loss: 303.8615 - mean_squared_error: 303.8615 - val_loss: 233.4845 - val_mean_squared_error: 233.4845
# Epoch 3/256
# 21/21 [==============================] - 0s 2ms/step - loss: 217.5952 - mean_squared_error: 217.5952 - val_loss: 178.4001 - val_mean_squared_error: 178.4001
# Epoch 4/256
# 21/21 [==============================] - 0s 3ms/step - loss: 168.3414 - mean_squared_error: 168.3414 - val_loss: 142.2493 - val_mean_squared_error: 142.2493
# Epoch 5/256
# 21/21 [==============================] - 0s 3ms/step - loss: 134.6293 - mean_squared_error: 134.6293 - val_loss: 114.1779 - val_mean_squared_error: 114.1779
# Epoch 6/256
# 21/21 [==============================] - 0s 2ms/step - loss: 107.3627 - mean_squared_error: 107.3627 - val_loss: 89.3095 - val_mean_squared_error: 89.3095
# Epoch 7/256
# 21/21 [==============================] - 0s 2ms/step - loss: 83.0772 - mean_squared_error: 83.0772 - val_loss: 65.3052 - val_mean_squared_error: 65.3052
# Epoch 8/256
# 21/21 [==============================] - 0s 3ms/step - loss: 59.4204 - mean_squared_error: 59.4204 - val_loss: 41.6650 - val_mean_squared_error: 41.6650
# Epoch 9/256
# 21/21 [==============================] - 0s 3ms/step - loss: 35.9162 - mean_squared_error: 35.9162 - val_loss: 20.4663 - val_mean_squared_error: 20.4663
# Epoch 10/256
# 21/21 [==============================] - 0s 2ms/step - loss: 16.2256 - mean_squared_error: 16.2256 - val_loss: 6.1979 - val_mean_squared_error: 6.1979
# Epoch 11/256
# 21/21 [==============================] - 0s 2ms/step - loss: 4.3168 - mean_squared_error: 4.3168 - val_loss: 0.7733 - val_mean_squared_error: 0.7733
# Epoch 12/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.4417 - mean_squared_error: 0.4417 - val_loss: 0.0452 - val_mean_squared_error: 0.0452
# Epoch 13/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0357 - mean_squared_error: 0.0357 - val_loss: 0.0376 - val_mean_squared_error: 0.0376
# Epoch 14/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0320 - mean_squared_error: 0.0320 - val_loss: 0.0322 - val_mean_squared_error: 0.0322
# Epoch 15/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0276 - mean_squared_error: 0.0276 - val_loss: 0.0309 - val_mean_squared_error: 0.0309
# Epoch 16/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0305 - val_mean_squared_error: 0.0305
# Epoch 17/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0248 - mean_squared_error: 0.0248 - val_loss: 0.0302 - val_mean_squared_error: 0.0302
# Epoch 18/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0252 - mean_squared_error: 0.0252 - val_loss: 0.0298 - val_mean_squared_error: 0.0298
# Epoch 19/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0268 - mean_squared_error: 0.0268 - val_loss: 0.0296 - val_mean_squared_error: 0.0296
# Epoch 20/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0260 - mean_squared_error: 0.0260 - val_loss: 0.0292 - val_mean_squared_error: 0.0292
# Epoch 21/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0258 - mean_squared_error: 0.0258 - val_loss: 0.0289 - val_mean_squared_error: 0.0289
# Epoch 22/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0257 - mean_squared_error: 0.0257 - val_loss: 0.0286 - val_mean_squared_error: 0.0286
# Epoch 23/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0240 - mean_squared_error: 0.0240 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
# Epoch 24/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0256 - mean_squared_error: 0.0256 - val_loss: 0.0283 - val_mean_squared_error: 0.0283
# Epoch 25/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0277 - mean_squared_error: 0.0277 - val_loss: 0.0281 - val_mean_squared_error: 0.0281
# Epoch 26/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0279 - val_mean_squared_error: 0.0279
# Epoch 27/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# Epoch 28/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# Epoch 29/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0272 - mean_squared_error: 0.0272 - val_loss: 0.0275 - val_mean_squared_error: 0.0275
# Epoch 30/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 31/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 32/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0236 - mean_squared_error: 0.0236 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# Epoch 33/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0269 - val_mean_squared_error: 0.0269
# Epoch 34/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 35/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0267 - val_mean_squared_error: 0.0267
# Epoch 36/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 37/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 38/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0266 - val_mean_squared_error: 0.0266
# Epoch 39/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 40/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 41/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 42/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 43/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 44/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 45/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0244 - mean_squared_error: 0.0244 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 46/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 47/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0265 - val_mean_squared_error: 0.0265
# Epoch 48/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 49/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 50/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 51/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0261 - val_mean_squared_error: 0.0261
# Epoch 52/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 0.0263 - val_mean_squared_error: 0.0263
# Epoch 53/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 54/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 55/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 56/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 57/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 58/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0257 - val_mean_squared_error: 0.0257
# Epoch 59/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# Epoch 60/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 61/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 62/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0208 - mean_squared_error: 0.0208 - val_loss: 0.0255 - val_mean_squared_error: 0.0255
# Epoch 63/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0262 - val_mean_squared_error: 0.0262
# Epoch 64/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0216 - mean_squared_error: 0.0216 - val_loss: 0.0254 - val_mean_squared_error: 0.0254
# Epoch 65/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0258 - val_mean_squared_error: 0.0258
# Epoch 66/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0279 - mean_squared_error: 0.0279 - val_loss: 0.0273 - val_mean_squared_error: 0.0273

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(history.history['mean_squared_error'])
plt.ylabel('Mean Squared Error')

plt.title('Training')
plt.subplot(1,2,2)
plt.yscale('log')
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation')
# Out:
# Text(0.5, 1.0, 'Validation')

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
wide_deep = concatenate([wide_branch, deep_branch_3], axis=1)
wide_deep = Dense(units=1, kernel_initializer=initializer)(wide_deep)
model = Model(inputs=[input_crossed, input_cat, input_num], outputs=wide_deep)
model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

history = model.fit([X_train_crossed, X_train_cat, X_train_num], y_train,
                    epochs=epochs, batch_size=batch_size, verbose=verbose, callbacks=callbacks,
                    validation_data=([X_test_crossed, X_test_cat, X_test_num], y_test))
# Out:
# Epoch 1/256
# 21/21 [==============================] - 1s 9ms/step - loss: 35.5176 - mean_squared_error: 35.5176 - val_loss: 7.2135 - val_mean_squared_error: 7.2135
# Epoch 2/256
# 21/21 [==============================] - 0s 3ms/step - loss: 3.5762 - mean_squared_error: 3.5762 - val_loss: 0.3391 - val_mean_squared_error: 0.3391
# Epoch 3/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.3789 - mean_squared_error: 0.3789 - val_loss: 0.0393 - val_mean_squared_error: 0.0393
# Epoch 4/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0354 - mean_squared_error: 0.0354 - val_loss: 0.0369 - val_mean_squared_error: 0.0369
# Epoch 5/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 6/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0271 - mean_squared_error: 0.0271 - val_loss: 0.0253 - val_mean_squared_error: 0.0253
# Epoch 7/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# Epoch 8/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0244 - val_mean_squared_error: 0.0244
# Epoch 9/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 10/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0251 - mean_squared_error: 0.0251 - val_loss: 0.0259 - val_mean_squared_error: 0.0259
# Epoch 11/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# Epoch 12/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 13/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 14/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 15/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 16/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0240 - val_mean_squared_error: 0.0240
# Epoch 17/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 18/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 19/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0226 - mean_squared_error: 0.0226 - val_loss: 0.0238 - val_mean_squared_error: 0.0238
# Epoch 20/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0213 - mean_squared_error: 0.0213 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# Epoch 21/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# Epoch 22/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 23/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0210 - mean_squared_error: 0.0210 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 24/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 25/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0280 - mean_squared_error: 0.0280 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 26/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 27/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0274 - mean_squared_error: 0.0274 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 28/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 29/256
# 21/21 [==============================] - 0s 3ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0246 - val_mean_squared_error: 0.0246
# Epoch 30/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 31/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 32/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 33/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 34/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 35/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 36/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 37/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 38/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 39/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0223 - mean_squared_error: 0.0223 - val_loss: 0.0237 - val_mean_squared_error: 0.0237
# Epoch 40/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0235 - val_mean_squared_error: 0.0235
# Epoch 41/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# Epoch 42/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 43/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 44/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 45/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0215 - mean_squared_error: 0.0215 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 46/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 47/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0235 - mean_squared_error: 0.0235 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 48/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0209 - mean_squared_error: 0.0209 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 49/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0239 - mean_squared_error: 0.0239 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 50/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0212 - mean_squared_error: 0.0212 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 51/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 52/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0233 - val_mean_squared_error: 0.0233
# Epoch 53/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0210 - mean_squared_error: 0.0210 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 54/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0214 - mean_squared_error: 0.0214 - val_loss: 0.0228 - val_mean_squared_error: 0.0228
# Epoch 55/256
# 21/21 [==============================] - 0s 2ms/step - loss: 0.0219 - mean_squared_error: 0.0219 - val_loss: 0.0233 - val_mean_squared_error: 0.0233

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.yscale('log')
plt.plot(history.history['mean_squared_error'])
plt.ylabel('Mean Squared Error')

plt.title('Training')
plt.subplot(1,2,2)
plt.yscale('log')
plt.plot(history.history['val_mean_squared_error'])
plt.title('Validation')
# Out:
# Text(0.5, 1.0, 'Validation')

# %%
plot_model(
    model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %% [markdown]
# ### Altering the Number of Layers

# %% [markdown]
# #### Cross Validation

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=10, shuffle=True, random_state=1234)

X_crossed = merc_info[cross_col_names].to_numpy()
X_cat     = merc_info[categorical_headers_ints].to_numpy()
X_num     = merc_info[numerical].to_numpy()
y         = merc_info['log_price'].to_numpy()

deep_branches = [
    deep_branch_0,
    deep_branch_1,
    deep_branch_2,
    deep_branch_3
]

eval_scores = {}
for model_no, deep_branch in enumerate(deep_branches):
    
    fold_no = 0
    eval_scores[model_no] = []
    for train_index, test_index in kf.split(X, y):
        X_train_crossed, X_test_crossed = X_crossed[train_index], X_crossed[test_index]
        X_train_cat,     X_test_cat     = X_cat[train_index],     X_cat[test_index]
        X_train_num,     X_test_num     = X_num[train_index],     X_num[test_index]
        y_train,         y_test         = y[train_index],         y[test_index]
        
        wide_deep = concatenate([wide_branch, deep_branch], axis=1)
        wide_deep = Dense(units=1, kernel_initializer=initializer)(wide_deep)
        model = Model(inputs=[input_crossed, input_cat, input_num], outputs=wide_deep)
        model.compile(optimizer=optimizer, loss=loss, metrics=metrics)
        history = model.fit([X_train_crossed, X_train_cat, X_train_num], y_train,
                            epochs=epochs, batch_size=batch_size, callbacks = callbacks, verbose=0)

        scores = model.evaluate([X_test_crossed, X_test_cat, X_test_num], y_test, verbose=0)
        print(f"SCORE FOR MODEL {model_no} FOLD {fold_no}: MSE = {round(scores[1], 5)})")
        
        eval_scores[model_no].append(scores[1])
    
        fold_no += 1
    print(f"MEAN SCORE FOR MODEL {model_no}: MSE = {round(np.mean(eval_scores[model_no]), 5)}")
# Out:
# SCORE FOR MODEL 0 FOLD 0: MSE = 0.04314)
# SCORE FOR MODEL 0 FOLD 1: MSE = 0.02525)
# SCORE FOR MODEL 0 FOLD 2: MSE = 0.01869)
# SCORE FOR MODEL 0 FOLD 3: MSE = 0.02373)
# SCORE FOR MODEL 0 FOLD 4: MSE = 0.02167)
# SCORE FOR MODEL 0 FOLD 5: MSE = 0.01993)
# SCORE FOR MODEL 0 FOLD 6: MSE = 0.01992)
# SCORE FOR MODEL 0 FOLD 7: MSE = 0.01776)
# SCORE FOR MODEL 0 FOLD 8: MSE = 0.02108)
# SCORE FOR MODEL 0 FOLD 9: MSE = 0.04421)
# MEAN SCORE FOR MODEL 0: MSE = 0.02554
# SCORE FOR MODEL 1 FOLD 0: MSE = 0.01799)
# SCORE FOR MODEL 1 FOLD 1: MSE = 0.02202)
# SCORE FOR MODEL 1 FOLD 2: MSE = 0.01871)
# SCORE FOR MODEL 1 FOLD 3: MSE = 0.02384)
# SCORE FOR MODEL 1 FOLD 4: MSE = 0.02103)
# SCORE FOR MODEL 1 FOLD 5: MSE = 0.01945)
# SCORE FOR MODEL 1 FOLD 6: MSE = 0.0203)
# SCORE FOR MODEL 1 FOLD 7: MSE = 0.01772)
# SCORE FOR MODEL 1 FOLD 8: MSE = 0.02108)
# SCORE FOR MODEL 1 FOLD 9: MSE = 0.04431)
# MEAN SCORE FOR MODEL 1: MSE = 0.02264
# SCORE FOR MODEL 2 FOLD 0: MSE = 0.01625)
# SCORE FOR MODEL 2 FOLD 1: MSE = 0.02233)
# SCORE FOR MODEL 2 FOLD 2: MSE = 0.01865)
# SCORE FOR MODEL 2 FOLD 3: MSE = 0.02317)
# SCORE FOR MODEL 2 FOLD 4: MSE = 0.02049)
# SCORE FOR MODEL 2 FOLD 5: MSE = 0.01941)
# SCORE FOR MODEL 2 FOLD 6: MSE = 0.01977)
# SCORE FOR MODEL 2 FOLD 7: MSE = 0.01936)
# SCORE FOR MODEL 2 FOLD 8: MSE = 0.02081)
# SCORE FOR MODEL 2 FOLD 9: MSE = 0.0458)
# MEAN SCORE FOR MODEL 2: MSE = 0.0226
# SCORE FOR MODEL 3 FOLD 0: MSE = 0.01629)
# SCORE FOR MODEL 3 FOLD 1: MSE = 0.02164)
# SCORE FOR MODEL 3 FOLD 2: MSE = 0.01864)
# SCORE FOR MODEL 3 FOLD 3: MSE = 0.02347)
# SCORE FOR MODEL 3 FOLD 4: MSE = 0.0207)
# SCORE FOR MODEL 3 FOLD 5: MSE = 0.02021)
# SCORE FOR MODEL 3 FOLD 6: MSE = 0.02023)
# SCORE FOR MODEL 3 FOLD 7: MSE = 0.01765)
# SCORE FOR MODEL 3 FOLD 8: MSE = 0.02397)
# SCORE FOR MODEL 3 FOLD 9: MSE = 0.0466)
# MEAN SCORE FOR MODEL 3: MSE = 0.02294

# %%
scores = [np.mean(eval_scores[k]) for k in eval_scores]
best_model = np.argmin(scores)

wide_deep = concatenate([wide_branch, deep_branches[best_model]], axis=1)
wide_deep = Dense(units=1, kernel_initializer=initializer)(wide_deep)
best_model = Model(inputs=[input_crossed, input_cat, input_num], outputs=wide_deep)
best_model.compile(optimizer=optimizer, loss=loss, metrics=metrics)

plot_model(
    best_model, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
from tensorflow.keras import Sequential

tf.keras.backend.set_floatx('float64')
X_mlp = merc_info[numerical]

for col in categorical_headers_ints:
    X_mlp = pd.concat([X_mlp,pd.get_dummies(merc_info[col], prefix=col)],axis=1)
    
X_mlp = X_mlp.to_numpy()

fold_no = 0
mlp_scores = []
for train_index, test_index in kf.split(X_mlp, y):
    X_train, X_test = X_mlp[train_index], X_mlp[test_index]
    y_train, y_test = y[train_index], y[test_index]

    mlp = Sequential()
    mlp.add(Dense(20, kernel_initializer=initializer))
    mlp.add(Dense(10, kernel_initializer=initializer))
    mlp.add(Dense(5, kernel_initializer=initializer))
    mlp.add(Dense(1, kernel_initializer=initializer))
    mlp.compile(optimizer=optimizer, loss=loss, metrics = metrics)
    history = mlp.fit(X_train, y_train,
                        epochs=epochs, batch_size=batch_size, callbacks = callbacks, verbose=0)

    scores = mlp.evaluate(X_test, y_test, verbose=0)
    print(f"SCORE FOR MODEL MLP FOLD {fold_no}: MSE = {round(scores[1], 5)})")

    mlp_scores.append(scores[1])

    fold_no += 1
    
print("MEAN SCORE FOR MODEL MLP: MSE =",np.mean(mlp_scores))
# Out:
# SCORE FOR MODEL MLP FOLD 0: MSE = 0.01801)
# SCORE FOR MODEL MLP FOLD 1: MSE = 0.02441)
# SCORE FOR MODEL MLP FOLD 2: MSE = 0.02017)
# SCORE FOR MODEL MLP FOLD 3: MSE = 0.03049)
# SCORE FOR MODEL MLP FOLD 4: MSE = 0.02909)
# SCORE FOR MODEL MLP FOLD 5: MSE = 0.02726)
# SCORE FOR MODEL MLP FOLD 6: MSE = 0.02159)
# SCORE FOR MODEL MLP FOLD 7: MSE = 0.01954)
# SCORE FOR MODEL MLP FOLD 8: MSE = 0.02229)
# SCORE FOR MODEL MLP FOLD 9: MSE = 0.04696)
# MEAN SCORE FOR MODEL MLP: MSE = 0.02598153930018281

# %%
mlp = Sequential()
mlp.add(Dense(20, kernel_initializer=initializer))
mlp.add(Dense(10, kernel_initializer=initializer))
mlp.add(Dense(5, kernel_initializer=initializer))
mlp.add(Dense(1, kernel_initializer=initializer))
mlp.compile(optimizer=optimizer, loss=loss, metrics = metrics)

plot_model(
    mlp, to_file='model.png', show_shapes=True, show_layer_names=True,
    rankdir='LR', expand_nested=False, dpi=96
)

# %%
best_model.fit([X_crossed, X_cat, X_num], y, validation_split=.2,
               epochs=epochs, batch_size=batch_size, verbose=0, callbacks=callbacks)
mlp.fit(X_mlp, y, validation_split=.2,
               epochs=epochs, batch_size=batch_size, verbose=0, callbacks=callbacks)

# %%
from pyCompare import blandAltman

data_1 = best_model.predict([X_crossed, X_cat, X_num]).reshape(-1)
data_2 = mlp.predict(X_mlp).reshape(-1)

blandAltman(data_1, data_2)

# %% [markdown]
# Looking at Bland-Altman plot, we can see that most of the data points are within the statistical error range. Less than 50% of the points lie outside of the range, indicating that there is some agreement between the tests. There is great clustering in the same area, except for a few outliers, so we can assume that the two models are fairly similar.  With the points outside of the range, we can assume there is still slight difference between the two models.

# %%
from sklearn import metrics as mt

r2 = mt.r2_score(data_1, data_2)
fig, ax = plt.subplots()

plt.plot(data_1, data_2, 'o')
ax.set_title('R^2 Plot')
print("R^2: ", r2)

m, b = np.polyfit(data_1, data_2, 1)
plt.plot(data_1, m*data_1 + b)
plt.show()

print("Residual Variance: " + str(1 - r2))
# Out:
# R^2:  0.9871835528701507
# Residual Variance: 0.012816447129849307

# %% [markdown]
# From the R^2 plot, we can calculate the residual variance to be about 0.0128%, meaning there is a very small amount of error because of the different models.

# %% [markdown]
# ## Exceptional Work (1 pt)

# %% [markdown]
# <ul>
#     <li> 5000 students: You have free reign to provide additional analyses. </li>
#     <li>One idea (<b>required for 7000 level students</b>): Capture the embedding weights from the deep network and (<b>if needed</b>) perform dimensionality reduction on the output of these embedding layers (<b>only if needed</b>). That is, pass the observations into the network, save the embedded weights (called embeddings), and then perform  dimensionality reduction in order to visualize results. Visualize and explain any clusters in the data. </li>
# </ul>

# %%
embeddings = []

# for each categorical variable
for col in categorical_headers_ints:
    name = col+'_embed'
    embeddings.append(name)
print("Embedding Categories: ", embeddings)
    
for cat in embeddings:
    temp_model = Model(inputs=model.input, outputs=model.get_layer(cat).output)
    out = temp_model.predict([X_crossed, X_cat, X_num])
    plt.title(cat)
    plt.scatter(out.T[0], out.T[1])
    plt.show()
# Out:
# Embedding Categories:  ['model_int_embed', 'transmission_int_embed', 'fuelType_int_embed']

# %% [markdown]
# Looking at these plots, we can see how the number of instances of each feature to help us understand how they relate to the prediction. For instance, model seems to have the largest number of instances, relating to the number of different types of model found in our dataset. We can analyze the clusters of each feature by plotting the embedding weights using TSNE below.

# %%
from sklearn.manifold import TSNE
weights = []
for layer in best_model.layers:
    if layer.name[:-6] in categorical_headers_ints:
        weights.append(layer.get_weights())

#extract weight vectors
weights = [w[0] for w in weights]
print(weights)

#t-sne on embedded weights
tsne = TSNE(n_components=2, random_state=2, verbose=1)
reduced_w = []
for embed in weights:
    tsne_w = tsne.fit_transform(embed)
    reduced_w.append(tsne_w)
# Out:
# [array([[ 2.3548024 ,  2.372432  , -1.1197648 ,  0.7650626 , -1.9910525 ],
#        [ 2.3620622 ,  2.2364428 , -1.0463712 ,  0.6656203 , -1.9070885 ],
#        [ 2.3426545 ,  2.5150483 , -1.1506181 ,  0.81675047, -2.0379245 ],
#        [ 2.383237  ,  2.5555875 , -1.1065502 ,  0.8958618 , -2.0997846 ],
#        [ 2.4124842 ,  2.6070244 , -1.0614347 ,  0.9595028 , -2.1529815 ],
#        [ 2.1514416 ,  2.1859496 , -1.2989298 ,  0.41735938, -1.704136  ],
#        [ 2.4308336 ,  2.347872  , -1.1017601 ,  0.76850325, -1.8781457 ],
#        [ 2.298263  ,  2.6409698 , -1.2498366 ,  0.852886  , -2.1335375 ],
#        [ 2.3474236 ,  2.6020727 , -1.19951   ,  0.8804252 , -2.1528914 ],
#        [ 2.3391702 ,  4.191647  , -1.5573891 ,  1.8667145 , -3.011535  ],
#        [ 2.3426027 ,  2.797257  , -1.1736529 ,  0.96053016, -2.2361445 ],
#        [ 2.3630342 ,  2.4381719 , -1.1023045 ,  0.7759563 , -2.0476682 ],
#        [ 2.1908941 ,  2.8309605 , -1.3365533 ,  0.8798579 , -2.1912994 ],
#        [ 2.3038256 ,  2.8028126 , -1.3180774 ,  0.96735317, -2.2098656 ],
#        [ 2.2890322 ,  3.0042145 , -1.348192  ,  1.0600133 , -2.2978776 ],
#        [ 2.2863834 ,  3.1243043 , -1.4051137 ,  1.12291   , -2.3570442 ],
#        [ 2.3414674 ,  2.9996266 , -1.27652   ,  1.1718557 , -2.3574104 ],
#        [ 2.1279528 ,  2.8447433 , -1.4623245 ,  0.9007641 , -2.0896688 ],
#        [ 2.3576934 ,  3.0656948 , -1.3039    ,  1.211902  , -2.431295  ],
#        [ 2.335104  ,  2.6414793 , -1.1848481 ,  0.90711117, -2.0752404 ],
#        [ 2.40921   ,  2.4948447 , -1.0610842 ,  0.87529963, -1.9881107 ],
#        [ 2.2708476 ,  2.839424  , -1.3118405 ,  0.948968  , -2.1478112 ],
#        [ 2.3032987 ,  2.474698  , -1.1900752 ,  0.81713617, -2.0055282 ],
#        [ 2.054182  ,  2.669508  , -1.5184342 ,  0.89671195, -2.0511909 ],
#        [ 2.1678927 ,  2.4246294 , -1.2227988 ,  0.6976291 , -1.9000057 ],
#        [ 2.108769  ,  2.2500374 , -1.3691038 ,  0.9030536 , -1.6712162 ],
#        [ 1.954421  ,  3.212489  , -1.707163  ,  0.9217516 , -2.646973  ]],
#       dtype=float32), array([[2.1174893, 1.5018518],
#        [2.0496182, 1.3663211],
#        [2.0558667, 1.876635 ],
#        [2.1068742, 1.5752332]], dtype=float32), array([[-1.1586024, -2.3218915],
#        [-2.192596 , -2.5922642],
#        [-2.5567155, -2.6447706],
#        [-1.2412846, -2.3326426]], dtype=float32)]
# [t-SNE] Computing 26 nearest neighbors...
# [t-SNE] Indexed 27 samples in 0.000s...
# [t-SNE] Computed neighbors for 27 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 27 / 27
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 42.792244
# [t-SNE] KL divergence after 1000 iterations: 0.473211
# [t-SNE] Computing 3 nearest neighbors...
# [t-SNE] Indexed 4 samples in 0.000s...
# [t-SNE] Computed neighbors for 4 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 4 / 4
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 44.566593
# [t-SNE] KL divergence after 500 iterations: 0.048726
# [t-SNE] Computing 3 nearest neighbors...
# [t-SNE] Indexed 4 samples in 0.000s...
# [t-SNE] Computed neighbors for 4 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 4 / 4
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 44.566593
# [t-SNE] KL divergence after 500 iterations: 0.048726

# %%
#plot embedded weights
plt.figure(figsize=(6, 6))
for i, w in enumerate(reduced_w):    
    plt.scatter(w[:,0], w[:,1], label=categorical_headers_ints[i])
plt.title('Embedded Weights')
plt.legend()
plt.show()

# %% [markdown]
# Using t-SNE on the embedded weights, we can map multi-dimensional data to two dimensions and visually compare the features. We can see how there are certain features, like the model_int, that have a very even, clustered distribution in one area of the plot. On the other hand, fuel_type is more spread out on the plot and does not show any clusters. Transmission does not appear in the TSNE plot, which could mean that it may be less related to the other features or for the prediction. Fuel type and model are the prominent features, but are still not entirely directly related to one another because they are not relatively close to each other.

# %%
#https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py
def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:.5f}'.format(height),
            xy=(rect.get_x() + rect.get_width() / 2, height),
            xytext=(0, 5),  # 5 points vertical offset
            textcoords="offset points",
            ha='center', va='bottom')
        
#plot embedded weights
fig, ax = plt.subplots(figsize=(8,8))

ax.set_xticks(range(len(reduced_w)))
ax.set_xticklabels(embeddings)
ax.set_title('Embedded Weights Magnitude')
ax.set_xlabel('Categorical Features')
ax.set_ylabel('Magnitude')

avg_w = [np.absolute(np.mean(w)) for w in reduced_w]
bar = ax.bar(range(len(reduced_w)), avg_w)

autolabel(bar)
plt.show()

# %% [markdown]
# In the bar chart, we can see the magnitude of the weights for the deep branch. Transmission and fuel type have the greatest and equal magnitude, so we can assume these features are equally good predictors for the log price. The model has the lowest magnitude, which could mean that this feature had lower influence in predicting the price.
